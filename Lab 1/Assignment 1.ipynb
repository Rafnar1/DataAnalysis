# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [13,21,22,35,51,56,60]
y = [11,22,13,24,15,26,7]
plt.plot(x, y, marker='o')

# %%
x1 = [13,11,23,12,14,15]
y1 = [4,12,14,15,16,25]
plt.scatter(x1,y1)
x2 = [14,12,17,18]
y2 = [1,2,6,9]
plt.scatter(x2,y2)
plt.show()

# %%
df.isnull().sum()
# Out:
# chemistry_che                     1286
# Website                            269
# University                           0
# Supervisors name                     1
# contact_email                        0
# Faculty                            253
# Panel                                0
# calculation                          0
# expertise_                         405
# Expertise                          421
# Other expertise                    621
# created_2                            0
# expertise_copy                     421
# contact_points_of_universities       0
# Expertises                           0
# dtype: int64

# %%
df['Panel'] = df['Panel'].str.split(',')
df = df.explode('Panel')
df
# Out:
#      chemistry_che                                            Website  \
# 0              NaN                                                NaN
# 0              NaN                                                NaN
# 1              NaN  https://www.lettere.uniroma1.it/users/giovanni...
# 2              NaN                                                NaN
# 3              NaN  https://publons.com/researcher/1412746/saul-ve...
# ...            ...                                                ...
# 1398           NaN            https://www.uni-tuebingen.de/plasmonics
# 1399           NaN  https://uni-tuebingen.de/fakultaeten/mathemati...
# 1400           NaN  https://www.gla.ac.uk/schools/law/staff/anneth...
# 1401           NaN  http://en.phed.uoa.gr/human-resources/teaching...
# 1402           NaN                 https://uni-tuebingen.de/de/174627
#
#                                           University         Supervisors name  \
# ...

# %%
data = np.random.normal(1,1,500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.random.normal(1,1,500)
#
# NameError: name 'np' is not defined

# %%
array = [45,50,36,59,28.0,42,55,67,33,35,40,50]
array.sort()
sum = 0
np.mean(array)
for i in array:
    sum += abs(i-45)**2
math.sqrt(134.36)
# Out:
# 11.591376104673682

# %%
123.16666666666667*11
# Out:
# 1354.8333333333335
